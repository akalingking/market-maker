# %% [markdown]
# ### OPTIMAL MARKET MAKING

# %%
import os
import sys
import logging
import matplotlib
import asyncio
import nest_asyncio
import warnings
from backtest.detail.clock import Clock
from backtest.dtype.instrument import Instrument, Instruments
from backtest.schema.instrument_schema import instrument_schema
from backtest.orderbook.file_data_source import FileDataSource

# %%
nest_asyncio.apply()
matplotlib.use('TkAgg')
# %matplotlib inline
logging.getLogger().setLevel(logging.ERROR)

# %% [markdown]
# ### 1. Motivation
# Determine the optimal trade execution to liquidate inventory with minimum trading cost and/or risk.

# %% [markdown]
# #### 2.1 State Parameters
#
# **Inventory**
#
# $\begin{array}{r,l}
# dq_t &=v_t dt +v dB_t\quad\quad(1)\\
# \textit{where:}&\\
# v_t &:\text{trade velocity}\\
# B_t &:\text{Wiener process}\\
# \end{array}$
#
# **Asset process**
#
# $\begin{array}{r,l}
# dS_t &= kv_tdt + \sigma dW_t\\
# \textit{where:}&\\
# \sigma &= \text{volatility}\\
# \end{array}$
#
# **Cash account**
#
# $\begin{array}{r,l}
# dX_t &= -v_tS_tdt - L(v_t)dt\\
# \textit{where:}&\\
# L &= \text{temporary market impact}\\
# \end{array}$

# %% [markdown]
# #### 3. Dynamic programming
# ...

# %% [markdown]
# #### 3.1 Optimization problem
# ...

# %% [markdown]
# #### 3.2 HJB equation
# ...

# %% [markdown]
# #### 3.3 Solution to PDE
# ...

# %% [markdown]
# #### 4. Numerical Solution
#
# ...

# %% [markdown]
# ### Reference
#
# [[^](https://www.smallake.kr/wp-content/uploads/2016/03/optliq.pdf)] Almgren and Chriss (2000). Optimal Execution of Portfolio Transactions
